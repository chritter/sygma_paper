# %%
# %matplotlib nbagg
import matplotlib.pyplot as plt
import numpy as np
import sygma as s
import os

# %%
## Parameter for standard best fit
iniZ_st=0.0126
imf_type_st='chabrier'
imf_bdys_st=[0.1,100] #based on paper p. 18 (and tests on p.19)
imf_yields_range_st=[0.8,100]  #0.8 based on calculations in paper p.19, paper uses 40Msun but then messses up plots, 100Msun good agreement.
sn1a_rate_st='exp' #based on paper .p. 23
exp_dtd_st=2e9  #based on paper p. 23
direct_norm_1a_st=0.016 #better fit #0.02, #based on paper p. 23 (a parameter, see also p22)
dt_st=7e6
transitionmass_st=8 #6.8 #chosen to match the AGB and massive star  intersection.
yield_interp_st='wiersma' # means we correct for initial abundance as in wiersma (independent if yields are net yields or not.)
netyields_on_st=True #tells the code we actual use tabula.ted net yields. 
wiersmamod_st=True
table_st='yield_tables/isotope_yield_table_portinari98_marigo01.txt'
exclude_masses_st=[] #needs to be empty else 60Msun exlcuded!, cannot justify NOT to use 6,7Msun
sn1a_table_st='yield_tables/sn1a_t03.txt'
iniabu_table_st='yield_tables/iniabu/iniab_solar_Wiersma.ppn'

# %%
s0n=s.sygma(iolevel=0,iniZ=0.02,imf_type=imf_type_st,
           imf_bdys=imf_bdys_st, 
           imf_yields_range=[1,30],
           sn1a_rate=sn1a_rate_st, 
           exp_dtd=exp_dtd_st, 
           direct_norm_1a=direct_norm_1a_st, 
            dt=dt_st,
           transitionmass=transitionmass_st,
           yield_interp='lin',
           netyields_on=False,
            wiersmamod=False,
           table='yield_tables/isotope_yield_table_MESA_only_fryer12_delay.txt',
           exclude_masses=exclude_masses_st,
           sn1a_table=sn1a_table_st,iniabu_table='yield_tables/iniabu/iniab2.0E-02GN93.ppn')

s0n_ye=s.sygma(iolevel=0,iniZ=0.02,imf_type=imf_type_st,
           imf_bdys=imf_bdys_st, 
           imf_yields_range=[1,30],
           sn1a_rate=sn1a_rate_st, 
           exp_dtd=exp_dtd_st, 
           direct_norm_1a=direct_norm_1a_st, 
            dt=dt_st,
           transitionmass=transitionmass_st,
           yield_interp='lin',
           netyields_on=False,
            wiersmamod=False,
           table='yield_tables/isotope_yield_table_MESA_only_ye.txt',
           exclude_masses=exclude_masses_st,
           sn1a_table=sn1a_table_st,iniabu_table='yield_tables/iniabu/iniab2.0E-02GN93.ppn')


s1n=s.sygma(iolevel=0,iniZ=0.001,imf_type=imf_type_st,
           imf_bdys=imf_bdys_st, 
           imf_yields_range=[1,30],
           sn1a_rate=sn1a_rate_st, 
           exp_dtd=exp_dtd_st, 
           direct_norm_1a=direct_norm_1a_st, 
            dt=dt_st,
           transitionmass=transitionmass_st,
           yield_interp='lin',
           netyields_on=False,
            wiersmamod=False,
           table='yield_tables/isotope_yield_table_MESA_only_fryer12_delay.txt',
           exclude_masses=exclude_masses_st,
           sn1a_table=sn1a_table_st,iniabu_table='yield_tables/iniabu/iniab1.0E-03GN93_alpha.ppn')


s1n_ye=s.sygma(iolevel=0,iniZ=0.001,imf_type=imf_type_st,
           imf_bdys=imf_bdys_st, 
           imf_yields_range=[1,30],
           sn1a_rate=sn1a_rate_st, 
           exp_dtd=exp_dtd_st, 
           direct_norm_1a=direct_norm_1a_st, 
            dt=dt_st,
           transitionmass=transitionmass_st,
           yield_interp='lin',
           netyields_on=False,
            wiersmamod=False,
           table='yield_tables/isotope_yield_table_MESA_only_ye.txt',
           exclude_masses=exclude_masses_st,
           sn1a_table=sn1a_table_st,iniabu_table='yield_tables/iniabu/iniab1.0E-03GN93_alpha.ppn')
# Out:
# SYGMA run in progress..
#    SYGMA run completed - Run time: 1.08s
# SYGMA run in progress..
#    SYGMA run completed - Run time: 1.1s
# SYGMA run in progress..
#    SYGMA run completed - Run time: 1.03s
# SYGMA run in progress..
#    SYGMA run completed - Run time: 0.98s

# %% [markdown]
# ## Fig. 11 (left)

# %%
# %matplotlib inline
plt.figure(432)
s0n.plot_table_remnant(fig=432,iniZ=0.02,marker='o',masses=[12,15,20,25],label='delay',
                       table='yield_tables/isotope_yield_table_MESA_only_fryer12_delay.txt',color='b',shape='--')
s0n.plot_table_remnant(fig=432,iniZ=0.02,marker='D',masses=[12,15,20,25],label='rapid',
                       table='yield_tables/isotope_yield_table_MESA_only_fryer12_rapid.txt',color='g',shape='--')
s0n.plot_table_remnant(fig=432,iniZ=0.02,marker='^',masses=[12,15,20,25],label='Ye',
                       table='yield_tables/isotope_yield_table_MESA_only_ye.txt',color='r',shape='-')
plt.legend(loc=2,fontsize=10)
plt.xlim(11,27)
plt.xlabel('Initial mass [M$_{\odot}$]');plt.ylabel('Remnant mass [M$_{\odot}$]')
plt.minorticks_off()
props = dict(boxstyle='square', facecolor='w', alpha=1)
ax=plt.gca()
ax.text(0.4, 0.9, 'Z=0.02', transform=ax.transAxes, fontsize=12,verticalalignment='top', bbox=props)  
fig=plt.gcf()        
fig.set_size_inches(6,4,forward=True)
plt.ylim(1,10)
# Out:
# (1, 10)

# %% [markdown]
# ## Fig. 11 (right)

# %%
# %matplotlib inline
plt.figure(432)
s0n.plot_table_remnant(fig=432,iniZ=0.001,marker='o',masses=[12,15,20,25],label='delay',
                       table='yield_tables/isotope_yield_table_MESA_only_fryer12_delay.txt',color='b',shape='--')
s0n.plot_table_remnant(fig=432,iniZ=0.001,marker='D',masses=[12,15,20,25],label='rapid',
                       table='yield_tables/isotope_yield_table_MESA_only_fryer12_rapid.txt',color='g',shape='--')
s0n.plot_table_remnant(fig=432,iniZ=0.001,marker='^',masses=[12,15,20,25],label='Ye',
                       table='yield_tables/isotope_yield_table_MESA_only_ye.txt',color='r',shape='-')
plt.legend(loc=2,fontsize=10)
plt.xlim(11,27)
plt.xlabel('Initial mass [M$_{\odot}$]');plt.ylabel('Remnant mass [M$_{\odot}$]')
plt.minorticks_off()
props = dict(boxstyle='square', facecolor='w', alpha=1)
ax=plt.gca()
ax.text(0.4, 0.9, 'Z=0.001', transform=ax.transAxes, fontsize=12,verticalalignment='top', bbox=props)  
fig=plt.gcf()        
fig.set_size_inches(6,4,forward=True)
plt.ylim(1,10)
plt.legend().set_visible(False)

# %% [markdown]
# ## Fig. 12

# %%
# %matplotlib inline
f, axarr = plt.subplots(3, 2)
markevery=10
props = dict(boxstyle='square', facecolor='w', alpha=1)
for specie in ['Total','C','N','O','Si','Fe']:
#specie='Ba-132'
        if specie=='Total':
            plt.sca(axarr[0, 0])
        if specie=='C':
            plt.sca(axarr[0, 1])
        elif specie=='N':
            plt.sca(axarr[1, 0])
        elif specie=='O':
            plt.sca(axarr[1, 1])
        elif specie=='Si':
            plt.sca(axarr[2, 0])
        elif specie=='Fe':
            plt.sca(axarr[2, 1])
            
        if specie == 'Total':
            
            markevery=8            
            #s0n.plot_totmasses(fig=1,markevery=markevery,color='r',marker='+')
            #s0w.plot_totmasses(fig=1,markevery=markevery+5,color='b',marker='x')
            s0n.plot_totmasses(fig=1,source='agb',markevery=markevery,color='r',marker='^')
            s0n_ye.plot_totmasses(fig=1,source='agb',markevery=markevery+5,color='b',marker='>')
            s0n.plot_totmasses(fig=1,source='massive',markevery=markevery,color='r',marker='D')
            s0n_ye.plot_totmasses(fig=1,source='massive',markevery=markevery+5,color='b',marker='o')
            #ax=plt.gca()
            #l2=ax.lines #[-8:]
            #plt.legend(l2,('Total, NuGrid','Total, W09','AGB, NuGrid','AGB, W09','Massive, NuGrid','Massive, W09'),loc=4,prop={'size': 12})
            #plt.show()
            #plt.plot([],[],marker='',linestyle='-.',color='k',label='AGBt',linewidth=3)
            #plt.plot([],[],marker='',linestyle='-',color='k',label='Massive',linewidth=3)            
            #ax=plt.gca()
            #l2=ax.lines[-2:]
            #plt.legend(l2,('AGB','Massive'),loc=6,prop={'size': 12}).set_visible(True)             
            
        else:  
            s0n.plot_mass(fig=1,specie=specie,source='agb',norm='no',color='b',label=specie+' (AGB), Z=2e-2',shape='-.',marker='^',markevery=markevery)
            s0n_ye.plot_mass(fig=1,specie=specie,source='agb',norm='no',color='r',label=specie+' (AGB), Z=2e-2',shape='-.',marker='>',markevery=markevery+5)
            s0n.plot_mass(fig=1,specie=specie,source='massive',norm='no',color='b',label=specie+' (massive), Z=2e-2',shape='-',marker='D',markevery=markevery)
            s0n_ye.plot_mass(fig=1,specie=specie,source='massive',norm='no',color='r',label=specie+' (massive), Z=2e-2',shape='-',marker='o',markevery=markevery+5)   
            #ax=plt.gca()
            #ax.text(0.85, 0.85, specie, transform=ax.transAxes, fontsize=16,verticalalignment='top', bbox=props)    
            plt.legend(loc=6,fontsize=12).set_visible(False)
        if specie in ['C',]:
            plt.ylim(1e-2,1e2)
        elif specie in ['Si']:
            plt.ylim(1e-1,2e1)
        elif specie in ['N']:
            plt.ylim(1e-1,2e1)
        elif specie in ['O']:
            plt.ylim(1e0,2e2)       
        elif specie in ['Fe']:
            plt.ylim(1e-1,1e1)
            
        #else:
        #    plt.ylim(1e5,1e8)
        ax=plt.gca()
        if specie=='Total':
            plt.plot([],[],marker='^',linestyle='-.',color='b',label='AGB')
            plt.plot([],[],marker='>',linestyle='-.',color='r',label='Massive')
            #plt.plot([],[],marker='+',linestyle=':',color='r',label='SNIa')
            plt.plot([],[],marker='D',linestyle='-',color='b',label='AGB')
            plt.plot([],[],marker='o',linestyle='-',color='r',label='Massive')
            l2=ax.lines[-4:]
            plt.legend(l2,('AGB, Fryer13','AGB, Ye','Massive, Fryer13','Massive, Ye'),loc=4,prop={'size': 14})
        ax=plt.gca()    
        #plt.legend().set_visible(False)
        if (specie=='N'):
            ax.set_ylabel(r'Accumulated ejecta [M$_{\odot}$]',size=20)
        #elif not ( ((specie=='Total') or ( specie=='N')) or ( specie=='Fe')):
        #    ax.get_yaxis().set_ticklabels([]) #set_visible(False)
        #    plt.ylabel('')
        else:
            plt.ylabel('')
        if specie in ['Total','C','N','O']:
            ax.get_xaxis().set_ticklabels([])
            plt.xlabel('')    
        else:
            plt.xlabel('log-scaled age [yrs]',size=20)
        plt.yscale('log')    
        ax=plt.gca()
        ax.text(0.1, 0.85, specie, transform=ax.transAxes, fontsize=16,verticalalignment='top', bbox=props)  
        #if not ( ((specie=='Total') or ( specie=='N')) or ( specie=='Fe')):
        #    ax.get_yaxis().set_ticklabels([])    
        if not specie =='Total':
            plt.ylim(1e-1,2e2)
#general settings
fig=plt.gcf()        
fig.set_size_inches(20,10) #figsize=(6, 4)
plt.subplots_adjust(hspace=0.1, bottom=0.125,wspace=0.15)#,left=0.1)
